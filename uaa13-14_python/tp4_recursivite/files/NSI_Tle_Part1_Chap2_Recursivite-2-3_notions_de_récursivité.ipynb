# %% [markdown]
# <h1 class="alert alert-info"><center>Récursivité (2/3) : notions de récursivité</center></h1>

# %% [markdown]
# Cette deuxième activité a pour but de manipuler quelques exemples classiques liées à la récursivité et d'en dégager quelques notions importantes.

# %% [markdown]
# <h2 class="alert alert-info">Exercice 1 : factorielle d'un entier naturel</h2>

# %% [markdown]
# En mathématiques, la **factorielle d'un entier naturel** $n$, notée $n!$, est définie de la manière suivante :
#  - $0!=1$
#  - $n!=1\times2\times...\times n$ pour $n\geq1$
#
# Ainsi :
#  - $1!=1$
#  - $2!=1\times2=2$
#  - $3!=1\times2\times3=6$
#  - etc.
#
# Par définition de la factorielle, on remarque que $n!=n\times(n-1)!$ pour tout entier $n\geq1$.
#
# En utilisant cette remarque, compléter le code de la fonction `fact` ci-dessous pour que l'appel `fact(n)` renvoie la valeur de $n!$.

# %%
def fact(n):
    assert isinstance(n, int) and n>=0
    if n == 0:
        return ...
    else:
        return n*...

# %% [markdown]
# Les cinq cellules ci-dessous permettent de tester votre code. Elles doivent toutes renvoyer `True` lors de leur exécution.

# %%
fact(0) == 1

# %%
fact(1) == 1

# %%
fact(2) == 2

# %%
fact(3) == 6

# %%
fact(5) == 120

# %% [markdown]
# 2. On exécute l'instruction `fact(4)`. Expliquer les appels successifs qui ont lieu.

# %% [markdown]
# <p style='color:gray; font-style:italic'>Ecrire la réponse ici</p>

# %% [markdown]
# 3. Vérifier le résultat de la question 2 en exécutant la cellule suivante :

# %%
from IPython.display import HTML
HTML("""<iframe src="https://www.recursionvisualizer.com/?function_definition=def%20fact%28n%29%3A%0A%20%20%20%20assert%20isinstance%28n%2C%20int%29%20and%20n%3E%3D0%0A%20%20%20%20if%20n%20%3D%3D%200%3A%0A%20%20%20%20%20%20%20%20return%201%0A%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20return%20n*fact%28n-1%29&function_call=fact%284%29" width="800" height="600" allowfullscreen style="border: 1px solid #e4e4e4;border-radius: 4px;" frameborder="0"></iframe>""")

# %% [markdown]
# <h2 class="alert alert-info">Exercice 2 : appels infinis ?</h2>

# %% [markdown]
# 1. On considère la fonction Python suivante :
# ```python
# def mystère(n):
#    if n > 5:
#        return 1
#    else:
#        return n + mystère(n+1)
# ```
# A l'aide de l'outil _Recursion Visualizer_ (cellule ci-dessous à exécuter), répondre aux questions suivantes :
#  - Que renvoie l'instruction `mystère(2)` ?
#  - Comment sont effectués les appels récursifs  ?

# %%
from IPython.display import HTML
HTML("""<iframe src="https://www.recursionvisualizer.com/?function_definition=def%20myst%C3%A8re%28n%29%3A%0A%20%20%20if%20n%20%3E%205%3A%0A%20%20%20%20%20%20%20return%201%0A%20%20%20else%3A%0A%20%20%20%20%20%20%20return%20n%20%2B%20myst%C3%A8re%28n%2B1%29&function_call=myst%C3%A8re%282%29" width="800" height="600" allowfullscreen style="border: 1px solid #e4e4e4;border-radius: 4px;" frameborder="0"></iframe>""")

# %% [markdown]
# <p style='color:gray; font-style:italic'>Ecrire la réponse ici</p>

# %% [markdown]
# 2. On modifie la fonction précédente comme suit :
# ```python
# def mystère_infini(n):
#    if n <= 2:
#        return 1
#    else:
#        return n + mystère_infini(n+1)
# ```
#
# - Que renvoie l'instruction `mystère_infini(2)` ?

# %% [markdown]
# <p style='color:gray; font-style:italic'>Ecrire la réponse ici</p>

# %% [markdown]
# - Que renvoie l'instruction `mystère_infini(3)` ? Pourquoi ? On pourra exécuter les deux cellules suivantes pour utiliser les outils de visualisation _Recursion Visualizer_ et _Python Tutor_.

# %%
from IPython.display import HTML
HTML("""<iframe src="https://www.recursionvisualizer.com/?function_definition=def%20myst%C3%A8re_infini%28n%29%3A%0A%20%20%20if%20n%20%3C%3D%202%3A%0A%20%20%20%20%20%20%20return%201%0A%20%20%20else%3A%0A%20%20%20%20%20%20%20return%20n%20%2B%20myst%C3%A8re_infini%28n%2B1%29&function_call=myst%C3%A8re_infini%283%29" width="800" height="600" allowfullscreen style="border: 1px solid #e4e4e4;border-radius: 4px;" frameborder="0"></iframe>""")

# %%
from tutor import tutor

def mystère_infini(n):
   if n <= 2:
       return 1
   else:
       return n + mystère_infini(n+1)

mystère_infini(3)

tutor()

# %% [markdown]
# <p style='color:gray; font-style:italic'>Ecrire la réponse ici</p>

# %% [markdown]
# <h2 class="alert alert-info">Exercice 3 : suite récurrente</h2>

# %% [markdown]
# $\{1,3,5,7,9,11,...\}$ est la suite numérique des nombres impairs de premier terme $u_0 = 1$ avec la relation de récurrence : $u_{n+1} = u_n + 2$ (pour calculer le terme suivant on ajoute 2 au précédent).
#
# On se donne à présent la suite numérique $(u_n)$ définie sur l'ensemble des entiers naturels par : $u_0 = 12$ (le premier terme de la suite) et la relation de récurrence $u_{n+1} = 3u_n + 1$ (ici pour calculer le terme suivant il faut multiplier le précédent par 3 et lui ajouter 1).

# %% [markdown]
# 1. Compléter la fonction suivante permettant de calculer le terme de rang $n$ de la suite $(u_n)$ de manière itérative :

# %%
def calcul_terme_itératif(n):
    u = ...
    for i in range(...):
        u = ...
    return u

# %% [markdown]
# Les trois cellules suivantes permettent de tester votre code. Elles doivent toutes renvoyer `True`.

# %%
calcul_terme_itératif(0) == 12

# %%
calcul_terme_itératif(25) == 10591107618037

# %%
calcul_terme_itératif(100) == 6442219009150141637955764122070265908776344025012

# %% [markdown]
# 2. Exécuter la cellule suivante et écrire la fonction `calcul_terme_récursif` suivante pour qu'elle renvoie la valeur du terme de rang $n$ de la suite $(u_n)$ de manière récursive. On déplacera les blocs par glisser-déposer vers la droite.

# %%
from IPython.display import IFrame
IFrame('https://www.codepuzzle.io/IPACPZ', width='100%', height=600)

# %% [markdown]
# <h2 class="alert alert-info">Exercice 4 : calcul de carrés</h2>

# %% [markdown]
# On souhaite écrire une fonction récursive `carre` prenant en paramètre un entier naturel `n` et renvoyant le carré de `n`.
#
# Pour trouver le lien entre `carre(n)` et `carre(n-1)` pour tout entier `n>1`, on peut utiliser la formule classique $(n+1)^2 = n^2 + 2n +1$.

# %% [markdown]
# 1. En remplaçant $n$ par $n-1$ dans la formule précédente, déterminer la relation entre `carre(n)` et `carre(n-1)`.

# %% [markdown]
# <p style='color:gray; font-style:italic'>Ecrire la réponse ici</p>

# %% [markdown]
# 2. Compléter alors la fonction suivante pour qu'elle corresponde à la documentation indiquée.

# %%
def carre(n):
    '''
    n est un entier naturel
    Calcule récursivement le carré de n et renvoie sa valeur
    '''
    assert ...
    if ... :
        return 0
    return ...

# %% [markdown]
# Les trois cellules suivantes permettent de tester votre code. Elles doivent toutes renvoyer `True`.

# %%
carre(0) == 0

# %%
carre(2) == 4

# %%
carre(11) == 121

# %% [markdown]
# 3. On exécute l'instruction `carre(4)`. Expliquer les appels et renvois successifs qui ont lieu.

# %% [markdown]
# <p style='color:gray; font-style:italic'>Ecrire la réponse ici</p>

# %% [markdown]
# 4. Vérifier le résultat de la question 3 en exécutant la cellule suivante :

# %%
from IPython.display import HTML
HTML("""<iframe src="https://www.recursionvisualizer.com/?function_definition=def%20carre%28n%29%3A%0A%20%20%20%20assert%20isinstance%28n%2C%20int%29%20and%20n%20%3E%3D%200%0A%20%20%20%20if%20n%20%3D%3D%200%3A%0A%20%20%20%20%20%20%20%20return%200%0A%20%20%20%20return%20carre%28n-1%29%20%2B%202*n%20-%201%0A%0A&function_call=carre%284%29" width="800" height="600" allowfullscreen style="border: 1px solid #e4e4e4;border-radius: 4px;" frameborder="0"></iframe>""")

# %% [markdown]
# <h2 class="alert alert-info">Exercice 5 : maximum dans une liste</h2>

# %% [markdown]
# Une méthode pour déterminer le maximum dans un tableau de nombres non vide est la suivante :
# - si le tableau ne contient qu'un seul élément : c'est le maximum ;
# - si le tableau contient au moins deux éléments, on le partage en deux sous-tableaux contenant le même nombre (éventuellement à un près) d'éléments et le maximum du tableau initial est alors le maximum du maximum de ces deux sous-tableaux.

# %% [markdown]
# 1. Justifier que la méthode proposée ci-dessus est une méthode qui induit naturellement un algorithme récursif.

# %% [markdown]
# <p style='color:gray; font-style:italic'>Ecrire la réponse ici</p>

# %% [markdown]
# On implémente cet algorithme de la façon suivante en Python (les tableaux sont ici assimilés aux données de type `list`) :
# ```python
# 1 def maximum(liste):
# 2     if len(liste) == 1:
# 3         return liste[0]
# 4     indice_milieu = len(liste)//2
# 5     max_gauche = maximum(liste[:indice_milieu])
# 6     max_droite = maximum(liste[indice_milieu:])
# 7     if max_gauche > max_droite:
# 8         return max_gauche
# 9     return max_droite
# ```
#
# On rappelle que si `L` est une liste et `m` un entier compris entre `1` et `len(L)-1`, alors
#  - l'instruction `L[:m]` renvoie une liste contenant les éléments de `L` d'indices allant de `0` à `m-1` ;
#  - l'instruction `L[m:]` renvoie une liste contenant les éléments de `L` d'indices allant de `m` à `len(L)-1`.
#
# Par exemple, si `L = [1, 5, 6, 3]`, alors `L[:2]` est la sous-liste `[1, 5]` et `L[2:]` est la sous-liste `[6, 3]`.

# %% [markdown]
# 2. Indiquer les numéros de lignes correspondant aux trois étapes de l'algorithme : cas de base, découpage en sous-listes et combinaison des résultats.

# %% [markdown]
# <p style='color:gray; font-style:italic'>Ecrire la réponse ici</p>

# %% [markdown]
# **On exécute à présent l'instruction `maximum([2,5,6,4,9,8,1])`**

# %% [markdown]
# 3. A l'aide de l'outil Recursion Visualizer (cellule ci-dessous à exécuter), expliquer comment sont gérés les multiples appels récursifs. En particulier, préciser dans quel ordre sont obtenus les différents calculs intermédiaires des maximums.

# %%
from IPython.display import HTML
HTML("""<iframe src="https://www.recursionvisualizer.com/?function_definition=def%20maximum%28liste%29%3A%0A%20%20%20%20if%20len%28liste%29%20%3D%3D%201%3A%0A%20%20%20%20%20%20%20%20return%20liste%5B0%5D%0A%20%20%20%20indice_milieu%20%3D%20len%28liste%29%2F%2F2%0A%20%20%20%20max_gauche%20%3D%20maximum%28liste%5B%3Aindice_milieu%5D%29%0A%20%20%20%20max_droite%20%3D%20maximum%28liste%5Bindice_milieu%3A%5D%29%0A%20%20%20%20if%20max_gauche%20%3E%20max_droite%3A%0A%20%20%20%20%20%20%20%20return%20max_gauche%0A%20%20%20%20return%20max_droite%0A%0A%0A%0A&function_call=maximum%28%5B2%2C5%2C6%2C4%2C9%2C8%2C1%5D%29" width="800" height="600" allowfullscreen style="border: 1px solid #e4e4e4;border-radius: 4px;" frameborder="0"></iframe>""")

# %% [markdown]
# <p style='color:gray; font-style:italic'>Ecrire la réponse ici</p>

# %% [markdown]
# 4. Exécuter la cellule suivante et dérouler l'exécution du code dans Python Tutor.

# %%
from tutor import tutor

def maximum(liste):
    if len(liste) == 1:
        return liste[0]
    indice_milieu = len(liste)//2
    max_gauche = maximum(liste[:indice_milieu])
    max_droite = maximum(liste[indice_milieu:])
    if max_gauche > max_droite:
        return max_gauche
    return max_droite

maximum([2,5,6,4,9,8,1])

tutor()

# %% [markdown]
# Comment interpréter d'un point de vue de la machine les différents blocs qui apparaissent et disparaissent dans la colonne `Frames` ?

# %% [markdown]
# <p style='color:gray; font-style:italic'>Ecrire la réponse ici</p>

# %% [markdown]
# <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img alt="Licence Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br />Ce document  est mis à disposition selon les termes de la <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Licence Creative Commons Attribution -  Partage dans les Mêmes Conditions 4.0 International</a>.
# Pour toute question : <a href="mailto:charles.poulmaire@ac-versailles.fr">charles.poulmaire@ac-versailles.fr</a> ou <a href="mailto:pascal.remy@ac-versailles.fr">pascal.remy@ac-versailles.fr</a>
